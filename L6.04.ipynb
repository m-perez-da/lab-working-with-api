# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from time import sleep
from random import randint
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("SpotifySecret.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['cs']))

# %%
# loading list of songs collected using scraping
repository = pd.read_csv('songs.csv')

# %%
repository
# Out:
#                      artist                                song
# 0                Pink Floyd  Another Brick in the Wall (part 2)
# 1          Barbra Streisand                     A Woman in Love
# 2               John Lennon           (Just Like) Starting Over
# 3                Diana Ross                         Upside Down
# 4                 Lipps Inc                           Funkytown
# ...                     ...                                 ...
# 1844  New Kids on the Block                       Hangin' Tough
# 1845         Gloria Estefan                Don't Wanna Lose You
# 1846          Milli Vanilli             Girl I'm Gonna Miss You
# 1847        Janet Jackson\n                       Miss You Much
# 1848          Milli Vanilli                Blame It on the Rain
#
# [1849 rows x 2 columns]

# %%
repository['artist']=repository['artist'].apply(lambda x: x.lower())
repository['song']=repository['song'].apply(lambda x: x.lower())
repository=repository.drop_duplicates()
repository=repository.reset_index()

# %%
repository=repository.drop(['index'], axis=1)

# %%
repository
# Out:
#                 artist                                song
# 0           pink floyd  another brick in the wall (part 2)
# 1     barbra streisand                     a woman in love
# 2          john lennon           (just like) starting over
# 3           diana ross                         upside down
# 4            lipps inc                           funkytown
# ...                ...                                 ...
# 1755            poison            every rose has its thorn
# 1756       bobby brown                      my prerogative
# 1757    gloria estefan                don't wanna lose you
# 1758     milli vanilli             girl i'm gonna miss you
# 1759   janet jackson\n                       miss you much
#
# [1760 rows x 2 columns]

# %%
# collecting audio features from Spotify
songs_uri=[]
songs_danceability=[]
songs_energy=[]
songs_key=[]
songs_loudness=[]
songs_mode=[]
songs_speechiness=[]
songs_acousticness=[]
songs_instrumentalness=[]
songs_liveness=[]
songs_valence=[]
songs_tempo=[]
songs_duration_ms=[]
songs_time_signature=[]

for i in range(len(repository)):
    results = sp.search(q=(repository.loc[i,'artist']+ ' ' +repository.loc[i,'song']), limit=1)
#    for j in range(len(results['tracks']['items'])):
#        results_artist=results['tracks']['items'][j]['artists'][0]['name']
#        results_song=results['tracks']['items'][j]['name']
#        print(repository2.loc[4,'artist'])
#         print(repository2.loc[i,'song'])
#        if ((repository.loc[12,'song']==results_song) & (repository.loc[12,'artist']==results_artist)):
# #            uri_id=results['tracks']['items'][0]['uri']
    if len(results['tracks']['items'])>0:
        songs_uri.append(results['tracks']['items'][0]['uri'])
        uri=results['tracks']['items'][0]['uri']
        results=sp.audio_features(uri)    
        songs_danceability.append(results[0]['danceability'])
        songs_energy.append(results[0]['energy'])
        songs_key.append(results[0]['key'])
        songs_loudness.append(results[0]['loudness'])
        songs_mode.append(results[0]['mode'])
        songs_speechiness.append(results[0]['speechiness'])
        songs_acousticness.append(results[0]['acousticness'])
        songs_instrumentalness.append(results[0]['instrumentalness'])
        songs_liveness.append(results[0]['liveness'])
        songs_valence.append(results[0]['valence'])
        songs_tempo.append(results[0]['tempo'])
        songs_duration_ms.append(results[0]['duration_ms'])
        songs_time_signature.append(results[0]['time_signature'])
    else:
        songs_uri.append('NA')
        songs_danceability.append('NA')
        songs_energy.append('NA')
        songs_key.append('NA')
        songs_loudness.append('NA')
        songs_mode.append('NA')
        songs_speechiness.append('NA')
        songs_acousticness.append('NA')
        songs_instrumentalness.append('NA')
        songs_liveness.append('NA')
        songs_valence.append('NA')
        songs_tempo.append('NA')
        songs_duration_ms.append('NA')
        songs_time_signature.append('NA')
    wait_time = randint(0,1)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
    print(i)
# Out:
# I will sleep for 1 second/s.
# 0
# I will sleep for 0 second/s.
# 1
# I will sleep for 0 second/s.
# 2
# I will sleep for 1 second/s.
# 3
# I will sleep for 0 second/s.
# 4
# I will sleep for 1 second/s.
# 5
# I will sleep for 1 second/s.
# 6
# I will sleep for 0 second/s.
# 7
# I will sleep for 1 second/s.
# 8
# I will sleep for 1 second/s.
# 9
# I will sleep for 0 second/s.
# 10
# I will sleep for 0 second/s.
# 11
# I will sleep for 1 second/s.
# 12
# I will sleep for 0 second/s.
# 13
# I will sleep for 0 second/s.
# 14
# I will sleep for 1 second/s.
# 15
# I will sleep for 1 second/s.
# 16
# I will sleep for 1 second/s.
# 17
# I will sleep for 0 second/s.
# 18
# I will sleep for 0 second/s.
# 19
# I will sleep for 1 second/s.
# 20
# I will sleep for 1 second/s.
# 21
# I will sleep for 0 second/s.
# 22
# I will sleep for 1 second/s.
# 23
# I will sleep for 0 second/s.
# 24
# I will sleep for 1 second/s.
# 25
# I will sleep for 1 second/s.
# 26
# I will sleep for 1 second/s.
# 27
# I will sleep for 0 second/s.
# 28
# I will sleep for 1 second/s.
# 29
# I will sleep for 0 second/s.
# 30
# I will sleep for 0 second/s.
# 31
# I will sleep for 1 second/s.
# 32
# I will sleep for 0 second/s.
# 33
# I will sleep for 0 second/s.
# 34
# I will sleep for 1 second/s.
# 35
# I will sleep for 0 second/s.
# 36
# I will sleep for 0 second/s.
# 37
# I will sleep for 0 second/s.
# 38
# I will sleep for 1 second/s.
# 39
# I will sleep for 0 second/s.
# 40
# I will sleep for 1 second/s.
# 41
# I will sleep for 0 second/s.
# 42
# I will sleep for 0 second/s.
# 43
# I will sleep for 0 second/s.
# 44
# I will sleep for 0 second/s.
# 45
# I will sleep for 1 second/s.
# 46
# I will sleep for 0 second/s.
# 47
# I will sleep for 0 second/s.
# 48
# I will sleep for 0 second/s.
# 49
# I will sleep for 1 second/s.
# 50
# I will sleep for 0 second/s.
# 51
# I will sleep for 1 second/s.
# 52
# I will sleep for 1 second/s.
# 53
# I will sleep for 0 second/s.
# 54
# I will sleep for 1 second/s.
# 55
# I will sleep for 1 second/s.
# 56
# I will sleep for 0 second/s.
# 57
# I will sleep for 1 second/s.
# 58
# I will sleep for 1 second/s.
# 59
# I will sleep for 0 second/s.
# 60
# I will sleep for 1 second/s.
# 61
# I will sleep for 1 second/s.
# 62
# I will sleep for 1 second/s.
# 63
# I will sleep for 1 second/s.
# 64
# I will sleep for 0 second/s.
# 65
# I will sleep for 0 second/s.
# 66
# I will sleep for 0 second/s.
# 67
# I will sleep for 1 second/s.
# 68
# I will sleep for 1 second/s.
# 69
# I will sleep for 0 second/s.
# 70
# I will sleep for 1 second/s.
# 71
# I will sleep for 0 second/s.
# 72
# I will sleep for 0 second/s.
# 73
# I will sleep for 0 second/s.
# 74
# I will sleep for 1 second/s.
# 75
# I will sleep for 1 second/s.
# 76
# I will sleep for 1 second/s.
# 77
# I will sleep for 0 second/s.
# 78
# I will sleep for 0 second/s.
# 79
# I will sleep for 0 second/s.
# 80
# I will sleep for 1 second/s.
# 81
# I will sleep for 0 second/s.
# 82
# I will sleep for 1 second/s.
# 83
# I will sleep for 1 second/s.
# 84
# I will sleep for 1 second/s.
# 85
# I will sleep for 1 second/s.
# 86
# I will sleep for 1 second/s.
# 87
# I will sleep for 1 second/s.
# 88
# I will sleep for 1 second/s.
# 89
# I will sleep for 0 second/s.
# 90
# I will sleep for 1 second/s.
# 91
# I will sleep for 0 second/s.
# 92
# I will sleep for 0 second/s.
# 93
# I will sleep for 1 second/s.
# 94
# I will sleep for 1 second/s.
# 95
# I will sleep for 0 second/s.
# 96
# I will sleep for 1 second/s.
# 97
# I will sleep for 1 second/s.
# 98
# I will sleep for 0 second/s.
# 99
# I will sleep for 1 second/s.
# 100
# I will sleep for 0 second/s.
# 101
# I will sleep for 0 second/s.
# 102
# I will sleep for 1 second/s.
# 103
# I will sleep for 1 second/s.
# 104
# I will sleep for 1 second/s.
# 105
# I will sleep for 0 second/s.
# 106
# I will sleep for 1 second/s.
# 107
# I will sleep for 0 second/s.
# 108
# I will sleep for 0 second/s.
# 109
# I will sleep for 1 second/s.
# 110
# I will sleep for 0 second/s.
# 111
# I will sleep for 0 second/s.
# 112
# I will sleep for 1 second/s.
# 113
# I will sleep for 0 second/s.
# 114
# I will sleep for 1 second/s.
# 115
# I will sleep for 0 second/s.
# 116
# I will sleep for 1 second/s.
# 117
# I will sleep for 1 second/s.
# 118
# I will sleep for 0 second/s.
# 119
# I will sleep for 1 second/s.
# 120
# I will sleep for 1 second/s.
# 121
# I will sleep for 0 second/s.
# 122
# I will sleep for 1 second/s.
# 123
# I will sleep for 1 second/s.
# 124
# I will sleep for 1 second/s.
# 125
# I will sleep for 0 second/s.
# 126
# I will sleep for 0 second/s.
# 127
# I will sleep for 1 second/s.
# 128
# I will sleep for 0 second/s.
# 129
# I will sleep for 1 second/s.
# 130
# I will sleep for 1 second/s.
# 131
# I will sleep for 0 second/s.
# 132
# I will sleep for 1 second/s.
# 133
# I will sleep for 1 second/s.
# 134
# I will sleep for 1 second/s.
# 135
# I will sleep for 0 second/s.
# 136
# I will sleep for 1 second/s.
# 137
# I will sleep for 1 second/s.
# 138
# I will sleep for 0 second/s.
# 139
# I will sleep for 1 second/s.
# 140
# I will sleep for 0 second/s.
# 141
# I will sleep for 1 second/s.
# 142
# I will sleep for 0 second/s.
# 143
# I will sleep for 1 second/s.
# 144
# I will sleep for 0 second/s.
# 145
# I will sleep for 1 second/s.
# 146
# I will sleep for 0 second/s.
# 147
# I will sleep for 1 second/s.
# 148
# I will sleep for 0 second/s.
# 149
# I will sleep for 0 second/s.
# 150
# I will sleep for 1 second/s.
# 151
# I will sleep for 0 second/s.
# 152
# I will sleep for 0 second/s.
# 153
# I will sleep for 1 second/s.
# 154
# I will sleep for 1 second/s.
# 155
# I will sleep for 0 second/s.
# 156
# I will sleep for 1 second/s.
# 157
# I will sleep for 1 second/s.
# 158
# I will sleep for 0 second/s.
# 159
# I will sleep for 1 second/s.
# 160
# I will sleep for 0 second/s.
# 161
# I will sleep for 1 second/s.
# 162
# I will sleep for 1 second/s.
# 163
# I will sleep for 0 second/s.
# 164
# I will sleep for 0 second/s.
# 165
# I will sleep for 0 second/s.
# 166
# I will sleep for 0 second/s.
# 167
# I will sleep for 1 second/s.
# 168
# I will sleep for 1 second/s.
# 169
# I will sleep for 0 second/s.
# 170
# I will sleep for 0 second/s.
# 171
# I will sleep for 1 second/s.
# 172
# I will sleep for 0 second/s.
# 173
# I will sleep for 1 second/s.
# 174
# I will sleep for 0 second/s.
# 175
# I will sleep for 1 second/s.
# 176
# I will sleep for 0 second/s.
# 177
# I will sleep for 1 second/s.
# 178
# I will sleep for 1 second/s.
# 179
# I will sleep for 0 second/s.
# 180
# I will sleep for 1 second/s.
# 181
# I will sleep for 1 second/s.
# 182
# I will sleep for 0 second/s.
# 183
# I will sleep for 1 second/s.
# 184
# I will sleep for 0 second/s.
# 185
# I will sleep for 0 second/s.
# 186
# I will sleep for 1 second/s.
# 187
# I will sleep for 0 second/s.
# 188
# I will sleep for 1 second/s.
# 189
# I will sleep for 0 second/s.
# 190
# I will sleep for 0 second/s.
# 191
# I will sleep for 0 second/s.
# 192
# I will sleep for 1 second/s.
# 193
# I will sleep for 0 second/s.
# 194
# I will sleep for 1 second/s.
# 195
# I will sleep for 1 second/s.
# 196
# I will sleep for 0 second/s.
# 197
# I will sleep for 1 second/s.
# 198
# I will sleep for 1 second/s.
# 199
# I will sleep for 1 second/s.
# 200
# I will sleep for 1 second/s.
# 201
# I will sleep for 0 second/s.
# 202
# I will sleep for 1 second/s.
# 203
# I will sleep for 1 second/s.
# 204
# I will sleep for 1 second/s.
# 205
# I will sleep for 1 second/s.
# 206
# I will sleep for 1 second/s.
# 207
# I will sleep for 0 second/s.
# 208
# I will sleep for 0 second/s.
# 209
# I will sleep for 1 second/s.
# 210
# I will sleep for 0 second/s.
# 211
# I will sleep for 1 second/s.
# 212
# I will sleep for 0 second/s.
# 213
# I will sleep for 0 second/s.
# 214
# I will sleep for 1 second/s.
# 215
# I will sleep for 1 second/s.
# 216
# I will sleep for 1 second/s.
# 217
# I will sleep for 1 second/s.
# 218
# I will sleep for 0 second/s.
# 219
# I will sleep for 1 second/s.
# 220
# I will sleep for 1 second/s.
# 221
# I will sleep for 0 second/s.
# 222
# I will sleep for 1 second/s.
# 223
# I will sleep for 1 second/s.
# 224
# I will sleep for 0 second/s.
# 225
# I will sleep for 1 second/s.
# 226
# I will sleep for 1 second/s.
# 227
# I will sleep for 1 second/s.
# 228
# I will sleep for 0 second/s.
# 229
# I will sleep for 0 second/s.
# 230
# I will sleep for 0 second/s.
# 231
# I will sleep for 1 second/s.
# 232
# I will sleep for 1 second/s.
# 233
# I will sleep for 1 second/s.
# 234
# I will sleep for 1 second/s.
# 235
# I will sleep for 0 second/s.
# 236
# I will sleep for 1 second/s.
# 237
# I will sleep for 0 second/s.
# 238
# I will sleep for 0 second/s.
# 239
# I will sleep for 1 second/s.
# 240
# I will sleep for 0 second/s.
# 241
# I will sleep for 0 second/s.
# 242
# I will sleep for 1 second/s.
# 243
# I will sleep for 0 second/s.
# 244
# I will sleep for 0 second/s.
# 245
# I will sleep for 0 second/s.
# 246
# I will sleep for 0 second/s.
# 247
# I will sleep for 1 second/s.
# 248
# I will sleep for 0 second/s.
# 249
# I will sleep for 0 second/s.
# 250
# I will sleep for 0 second/s.
# 251
# I will sleep for 0 second/s.
# 252
# I will sleep for 0 second/s.
# 253
# I will sleep for 1 second/s.
# 254
# I will sleep for 0 second/s.
# 255
# I will sleep for 1 second/s.
# 256
# I will sleep for 0 second/s.
# 257
# I will sleep for 0 second/s.
# 258
# I will sleep for 0 second/s.
# 259
# I will sleep for 1 second/s.
# 260
# I will sleep for 1 second/s.
# 261
# I will sleep for 1 second/s.
# 262
# I will sleep for 0 second/s.
# 263
# I will sleep for 1 second/s.
# 264
# I will sleep for 1 second/s.
# 265
# I will sleep for 1 second/s.
# 266
# I will sleep for 1 second/s.
# 267
# I will sleep for 0 second/s.
# 268
# I will sleep for 0 second/s.
# 269
# I will sleep for 0 second/s.
# 270
# I will sleep for 1 second/s.
# 271
# I will sleep for 1 second/s.
# 272
# I will sleep for 0 second/s.
# 273
# I will sleep for 0 second/s.
# 274
# I will sleep for 1 second/s.
# 275
# I will sleep for 1 second/s.
# 276
# I will sleep for 0 second/s.
# 277
# I will sleep for 1 second/s.
# 278
# I will sleep for 0 second/s.
# 279
# I will sleep for 1 second/s.
# 280
# I will sleep for 1 second/s.
# 281
# I will sleep for 1 second/s.
# 282
# I will sleep for 0 second/s.
# 283
# I will sleep for 0 second/s.
# 284
# I will sleep for 0 second/s.
# 285
# I will sleep for 1 second/s.
# 286
# I will sleep for 1 second/s.
# 287
# I will sleep for 0 second/s.
# 288
# I will sleep for 1 second/s.
# 289
# I will sleep for 1 second/s.
# 290
# I will sleep for 1 second/s.
# 291
# I will sleep for 1 second/s.
# 292
# I will sleep for 0 second/s.
# 293
# I will sleep for 1 second/s.
# 294
# I will sleep for 0 second/s.
# 295
# I will sleep for 1 second/s.
# 296
# I will sleep for 1 second/s.
# 297
# I will sleep for 1 second/s.
# 298
# I will sleep for 1 second/s.
# 299
# I will sleep for 0 second/s.
# 300
# I will sleep for 1 second/s.
# 301
# I will sleep for 0 second/s.
# 302
# I will sleep for 1 second/s.
# 303
# I will sleep for 0 second/s.
# 304
# I will sleep for 1 second/s.
# 305
# I will sleep for 0 second/s.
# 306
# I will sleep for 1 second/s.
# 307
# I will sleep for 0 second/s.
# 308
# I will sleep for 0 second/s.
# 309
# I will sleep for 0 second/s.
# 310
# I will sleep for 1 second/s.
# 311
# I will sleep for 1 second/s.
# 312
# I will sleep for 0 second/s.
# 313
# I will sleep for 1 second/s.
# 314
# I will sleep for 1 second/s.
# 315
# I will sleep for 0 second/s.
# 316
# I will sleep for 0 second/s.
# 317
# I will sleep for 1 second/s.
# 318
# I will sleep for 0 second/s.
# 319
# I will sleep for 0 second/s.
# 320
# I will sleep for 1 second/s.
# 321
# I will sleep for 1 second/s.
# 322
# I will sleep for 1 second/s.
# 323
# I will sleep for 0 second/s.
# 324
# I will sleep for 0 second/s.
# 325
# I will sleep for 0 second/s.
# 326
# I will sleep for 1 second/s.
# 327
# I will sleep for 1 second/s.
# 328
# I will sleep for 1 second/s.
# 329
# I will sleep for 0 second/s.
# 330
# I will sleep for 0 second/s.
# 331
# I will sleep for 0 second/s.
# 332
# I will sleep for 0 second/s.
# 333
# I will sleep for 0 second/s.
# 334
# I will sleep for 0 second/s.
# 335
# I will sleep for 0 second/s.
# 336
# I will sleep for 1 second/s.
# 337
# I will sleep for 1 second/s.
# 338
# I will sleep for 0 second/s.
# 339
# I will sleep for 0 second/s.
# 340
# I will sleep for 1 second/s.
# 341
# I will sleep for 1 second/s.
# 342
# I will sleep for 1 second/s.
# 343
# I will sleep for 1 second/s.
# 344
# I will sleep for 1 second/s.
# 345
# I will sleep for 1 second/s.
# 346
# I will sleep for 1 second/s.
# 347
# I will sleep for 0 second/s.
# 348
# I will sleep for 0 second/s.
# 349
# I will sleep for 1 second/s.
# 350
# I will sleep for 1 second/s.
# 351
# I will sleep for 1 second/s.
# 352
# I will sleep for 0 second/s.
# 353
# I will sleep for 1 second/s.
# 354
# I will sleep for 0 second/s.
# 355
# I will sleep for 0 second/s.
# 356
# I will sleep for 1 second/s.
# 357
# I will sleep for 0 second/s.
# 358
# I will sleep for 0 second/s.
# 359
# I will sleep for 1 second/s.
# 360
# I will sleep for 0 second/s.
# 361
# I will sleep for 1 second/s.
# 362
# I will sleep for 0 second/s.
# 363
# I will sleep for 0 second/s.
# 364
# I will sleep for 1 second/s.
# 365
# I will sleep for 1 second/s.
# 366
# I will sleep for 0 second/s.
# 367
# I will sleep for 1 second/s.
# 368
# I will sleep for 0 second/s.
# 369
# I will sleep for 1 second/s.
# 370
# I will sleep for 1 second/s.
# 371
# I will sleep for 1 second/s.
# 372
# I will sleep for 0 second/s.
# 373
# I will sleep for 1 second/s.
# 374
# I will sleep for 1 second/s.
# 375
# I will sleep for 0 second/s.
# 376
# I will sleep for 1 second/s.
# 377
# I will sleep for 1 second/s.
# 378
# I will sleep for 0 second/s.
# 379
# I will sleep for 0 second/s.
# 380
# I will sleep for 0 second/s.
# 381
# I will sleep for 0 second/s.
# 382
# I will sleep for 0 second/s.
# 383
# I will sleep for 0 second/s.
# 384
# I will sleep for 1 second/s.
# 385
# I will sleep for 1 second/s.
# 386
# I will sleep for 0 second/s.
# 387
# I will sleep for 0 second/s.
# 388
# I will sleep for 0 second/s.
# 389
# I will sleep for 0 second/s.
# 390
# I will sleep for 1 second/s.
# 391
# I will sleep for 1 second/s.
# 392
# I will sleep for 0 second/s.
# 393
# I will sleep for 1 second/s.
# 394
# I will sleep for 0 second/s.
# 395
# I will sleep for 1 second/s.
# 396
# I will sleep for 1 second/s.
# 397
# I will sleep for 1 second/s.
# 398
# I will sleep for 1 second/s.
# 399
# I will sleep for 0 second/s.
# 400
# I will sleep for 1 second/s.
# 401
# I will sleep for 0 second/s.
# 402
# I will sleep for 0 second/s.
# 403
# I will sleep for 0 second/s.
# 404
# I will sleep for 0 second/s.
# 405
# I will sleep for 0 second/s.
# 406
# I will sleep for 1 second/s.
# 407
# I will sleep for 0 second/s.
# 408
# I will sleep for 1 second/s.
# 409
# I will sleep for 0 second/s.
# 410
# I will sleep for 1 second/s.
# 411
# I will sleep for 0 second/s.
# 412
# I will sleep for 0 second/s.
# 413
# I will sleep for 0 second/s.
# 414
# I will sleep for 0 second/s.
# 415
# I will sleep for 1 second/s.
# 416
# I will sleep for 1 second/s.
# 417
# I will sleep for 1 second/s.
# 418
# I will sleep for 0 second/s.
# 419
# I will sleep for 1 second/s.
# 420
# I will sleep for 0 second/s.
# 421
# I will sleep for 0 second/s.
# 422
# I will sleep for 0 second/s.
# 423
# I will sleep for 0 second/s.
# 424
# I will sleep for 0 second/s.
# 425
# I will sleep for 0 second/s.
# 426
# I will sleep for 1 second/s.
# 427
# I will sleep for 1 second/s.
# 428
# I will sleep for 1 second/s.
# 429
# I will sleep for 0 second/s.
# 430
# I will sleep for 1 second/s.
# 431
# I will sleep for 0 second/s.
# 432
# I will sleep for 0 second/s.
# 433
# I will sleep for 1 second/s.
# 434
# I will sleep for 1 second/s.
# 435
# I will sleep for 1 second/s.
# 436
# I will sleep for 0 second/s.
# 437
# I will sleep for 1 second/s.
# 438
# I will sleep for 1 second/s.
# 439
# I will sleep for 0 second/s.
# 440
# I will sleep for 1 second/s.
# 441
# I will sleep for 1 second/s.
# 442
# I will sleep for 0 second/s.
# 443
# I will sleep for 0 second/s.
# 444
# I will sleep for 0 second/s.
# 445
# I will sleep for 1 second/s.
# 446
# I will sleep for 1 second/s.
# 447
# I will sleep for 1 second/s.
# 448
# I will sleep for 0 second/s.
# 449
# I will sleep for 1 second/s.
# 450
# I will sleep for 1 second/s.
# 451
# I will sleep for 1 second/s.
# 452
# I will sleep for 0 second/s.
# 453
# I will sleep for 0 second/s.
# 454
# I will sleep for 0 second/s.
# 455
# I will sleep for 0 second/s.
# 456
# I will sleep for 0 second/s.
# 457
# I will sleep for 0 second/s.
# 458
# I will sleep for 0 second/s.
# 459
# I will sleep for 1 second/s.
# 460
# I will sleep for 0 second/s.
# 461
# I will sleep for 0 second/s.
# 462
# I will sleep for 1 second/s.
# 463
# I will sleep for 0 second/s.
# 464
# I will sleep for 1 second/s.
# 465
# I will sleep for 1 second/s.
# 466
# I will sleep for 1 second/s.
# 467
# I will sleep for 1 second/s.
# 468
# I will sleep for 0 second/s.
# 469
# I will sleep for 0 second/s.
# 470
# I will sleep for 1 second/s.
# 471
# I will sleep for 0 second/s.
# 472
# I will sleep for 1 second/s.
# 473
# I will sleep for 0 second/s.
# 474
# I will sleep for 0 second/s.
# 475
# I will sleep for 0 second/s.
# 476
# I will sleep for 1 second/s.
# 477
# I will sleep for 1 second/s.
# 478
# I will sleep for 1 second/s.
# 479
# I will sleep for 0 second/s.
# 480
# I will sleep for 1 second/s.
# 481
# I will sleep for 1 second/s.
# 482
# I will sleep for 1 second/s.
# 483
# I will sleep for 1 second/s.
# 484
# I will sleep for 0 second/s.
# 485
# I will sleep for 1 second/s.
# 486
# I will sleep for 0 second/s.
# 487
# I will sleep for 0 second/s.
# 488
# I will sleep for 0 second/s.
# 489
# I will sleep for 1 second/s.
# 490
# I will sleep for 0 second/s.
# 491
# I will sleep for 0 second/s.
# 492
# I will sleep for 1 second/s.
# 493
# I will sleep for 1 second/s.
# 494
# I will sleep for 1 second/s.
# 495
# I will sleep for 0 second/s.
# 496
# I will sleep for 1 second/s.
# 497
# I will sleep for 0 second/s.
# 498
# I will sleep for 0 second/s.
# 499
# I will sleep for 1 second/s.
# 500
# I will sleep for 1 second/s.
# 501
# I will sleep for 1 second/s.
# 502
# I will sleep for 0 second/s.
# 503
# I will sleep for 0 second/s.
# 504
# I will sleep for 0 second/s.
# 505
# I will sleep for 1 second/s.
# 506
# I will sleep for 0 second/s.
# 507
# I will sleep for 0 second/s.
# 508
# I will sleep for 1 second/s.
# 509
# I will sleep for 1 second/s.
# 510
# I will sleep for 0 second/s.
# 511
# I will sleep for 0 second/s.
# 512
# I will sleep for 0 second/s.
# 513
# I will sleep for 1 second/s.
# 514
# I will sleep for 1 second/s.
# 515
# I will sleep for 1 second/s.
# 516
# I will sleep for 1 second/s.
# 517
# I will sleep for 0 second/s.
# 518
# I will sleep for 1 second/s.
# 519
# I will sleep for 1 second/s.
# 520
# I will sleep for 0 second/s.
# 521
# I will sleep for 0 second/s.
# 522
# I will sleep for 1 second/s.
# 523
# I will sleep for 1 second/s.
# 524
# I will sleep for 1 second/s.
# 525
# I will sleep for 1 second/s.
# 526
# I will sleep for 1 second/s.
# 527
# I will sleep for 1 second/s.
# 528
# I will sleep for 1 second/s.
# 529
# I will sleep for 0 second/s.
# 530
# I will sleep for 1 second/s.
# 531
# I will sleep for 1 second/s.
# 532
# I will sleep for 1 second/s.
# 533
# I will sleep for 0 second/s.
# 534
# I will sleep for 1 second/s.
# 535
# I will sleep for 1 second/s.
# 536
# I will sleep for 0 second/s.
# 537
# I will sleep for 0 second/s.
# 538
# I will sleep for 1 second/s.
# 539
# I will sleep for 1 second/s.
# 540
# I will sleep for 1 second/s.
# 541
# I will sleep for 0 second/s.
# 542
# I will sleep for 1 second/s.
# 543
# I will sleep for 1 second/s.
# 544
# I will sleep for 0 second/s.
# 545
# I will sleep for 1 second/s.
# 546
# I will sleep for 0 second/s.
# 547
# I will sleep for 1 second/s.
# 548
# I will sleep for 1 second/s.
# 549
# I will sleep for 1 second/s.
# 550
# I will sleep for 0 second/s.
# 551
# I will sleep for 0 second/s.
# 552
# I will sleep for 1 second/s.
# 553
# I will sleep for 1 second/s.
# 554
# I will sleep for 0 second/s.
# 555
# I will sleep for 1 second/s.
# 556
# I will sleep for 0 second/s.
# 557
# I will sleep for 0 second/s.
# 558
# I will sleep for 0 second/s.
# 559
# I will sleep for 0 second/s.
# 560
# I will sleep for 1 second/s.
# 561
# I will sleep for 1 second/s.
# 562
# I will sleep for 0 second/s.
# 563
# I will sleep for 0 second/s.
# 564
# I will sleep for 1 second/s.
# 565
# I will sleep for 1 second/s.
# 566
# I will sleep for 1 second/s.
# 567
# I will sleep for 1 second/s.
# 568
# I will sleep for 1 second/s.
# 569
# I will sleep for 1 second/s.
# 570
# I will sleep for 0 second/s.
# 571
# I will sleep for 0 second/s.
# 572
# I will sleep for 0 second/s.
# 573
# I will sleep for 1 second/s.
# 574
# I will sleep for 1 second/s.
# 575
# I will sleep for 0 second/s.
# 576
# I will sleep for 0 second/s.
# 577
# I will sleep for 1 second/s.
# 578
# I will sleep for 0 second/s.
# 579
# I will sleep for 0 second/s.
# 580
# I will sleep for 1 second/s.
# 581
# I will sleep for 1 second/s.
# 582
# I will sleep for 1 second/s.
# 583
# I will sleep for 1 second/s.
# 584
# I will sleep for 0 second/s.
# 585
# I will sleep for 1 second/s.
# 586
# I will sleep for 0 second/s.
# 587
# I will sleep for 0 second/s.
# 588
# I will sleep for 0 second/s.
# 589
# I will sleep for 1 second/s.
# 590
# I will sleep for 0 second/s.
# 591
# I will sleep for 0 second/s.
# 592
# I will sleep for 1 second/s.
# 593
# I will sleep for 1 second/s.
# 594
# I will sleep for 0 second/s.
# 595
# I will sleep for 1 second/s.
# 596
# I will sleep for 1 second/s.
# 597
# I will sleep for 1 second/s.
# 598
# I will sleep for 1 second/s.
# 599
# I will sleep for 1 second/s.
# 600
# I will sleep for 0 second/s.
# 601
# I will sleep for 0 second/s.
# 602
# I will sleep for 0 second/s.
# 603
# I will sleep for 0 second/s.
# 604
# I will sleep for 1 second/s.
# 605
# I will sleep for 0 second/s.
# 606
# I will sleep for 0 second/s.
# 607
# I will sleep for 0 second/s.
# 608
# I will sleep for 0 second/s.
# 609
# I will sleep for 0 second/s.
# 610
# I will sleep for 0 second/s.
# 611
# I will sleep for 0 second/s.
# 612
# I will sleep for 1 second/s.
# 613
# I will sleep for 1 second/s.
# 614
# I will sleep for 0 second/s.
# 615
# I will sleep for 1 second/s.
# 616
# I will sleep for 0 second/s.
# 617
# I will sleep for 1 second/s.
# 618
# I will sleep for 0 second/s.
# 619
# I will sleep for 0 second/s.
# 620
# I will sleep for 0 second/s.
# 621
# I will sleep for 0 second/s.
# 622
# I will sleep for 1 second/s.
# 623
# I will sleep for 1 second/s.
# 624
# I will sleep for 1 second/s.
# 625
# I will sleep for 0 second/s.
# 626
# I will sleep for 1 second/s.
# 627
# I will sleep for 0 second/s.
# 628
# I will sleep for 0 second/s.
# 629
# I will sleep for 1 second/s.
# 630
# I will sleep for 0 second/s.
# 631
# I will sleep for 1 second/s.
# 632
# I will sleep for 0 second/s.
# 633
# I will sleep for 0 second/s.
# 634
# I will sleep for 1 second/s.
# 635
# I will sleep for 1 second/s.
# 636
# I will sleep for 0 second/s.
# 637
# I will sleep for 0 second/s.
# 638
# I will sleep for 1 second/s.
# 639
# I will sleep for 1 second/s.
# 640
# I will sleep for 1 second/s.
# 641
# I will sleep for 1 second/s.
# 642
# I will sleep for 1 second/s.
# 643
# I will sleep for 1 second/s.
# 644
# I will sleep for 1 second/s.
# 645
# I will sleep for 1 second/s.
# 646
# I will sleep for 0 second/s.
# 647
# I will sleep for 1 second/s.
# 648
# I will sleep for 0 second/s.
# 649
# I will sleep for 0 second/s.
# 650
# I will sleep for 1 second/s.
# 651
# I will sleep for 1 second/s.
# 652
# I will sleep for 0 second/s.
# 653
# I will sleep for 0 second/s.
# 654
# I will sleep for 0 second/s.
# 655
# I will sleep for 0 second/s.
# 656
# I will sleep for 0 second/s.
# 657
# I will sleep for 0 second/s.
# 658
# I will sleep for 1 second/s.
# 659
# I will sleep for 1 second/s.
# 660
# I will sleep for 0 second/s.
# 661
# I will sleep for 0 second/s.
# 662
# I will sleep for 1 second/s.
# 663
# I will sleep for 1 second/s.
# 664
# I will sleep for 1 second/s.
# 665
# I will sleep for 1 second/s.
# 666
# I will sleep for 0 second/s.
# 667
# I will sleep for 0 second/s.
# 668
# I will sleep for 0 second/s.
# 669
# I will sleep for 0 second/s.
# 670
# I will sleep for 0 second/s.
# 671
# I will sleep for 0 second/s.
# 672
# I will sleep for 0 second/s.
# 673
# I will sleep for 1 second/s.
# 674
# I will sleep for 1 second/s.
# 675
# I will sleep for 1 second/s.
# 676
# I will sleep for 0 second/s.
# 677
# I will sleep for 1 second/s.
# 678
# I will sleep for 1 second/s.
# 679
# I will sleep for 0 second/s.
# 680
# I will sleep for 0 second/s.
# 681
# I will sleep for 0 second/s.
# 682
# I will sleep for 1 second/s.
# 683
# I will sleep for 0 second/s.
# 684
# I will sleep for 0 second/s.
# 685
# I will sleep for 1 second/s.
# 686
# I will sleep for 1 second/s.
# 687
# I will sleep for 1 second/s.
# 688
# I will sleep for 1 second/s.
# 689
# I will sleep for 1 second/s.
# 690
# I will sleep for 1 second/s.
# 691
# I will sleep for 0 second/s.
# 692
# I will sleep for 1 second/s.
# 693
# I will sleep for 0 second/s.
# 694
# I will sleep for 0 second/s.
# 695
# I will sleep for 0 second/s.
# 696
# I will sleep for 1 second/s.
# 697
# I will sleep for 0 second/s.
# 698
# I will sleep for 0 second/s.
# 699
# I will sleep for 1 second/s.
# 700
# I will sleep for 0 second/s.
# 701
# I will sleep for 1 second/s.
# 702
# I will sleep for 1 second/s.
# 703
# I will sleep for 0 second/s.
# 704
# I will sleep for 1 second/s.
# 705
# I will sleep for 0 second/s.
# 706
# I will sleep for 0 second/s.
# 707
# I will sleep for 0 second/s.
# 708
# I will sleep for 1 second/s.
# 709
# I will sleep for 1 second/s.
# 710
# I will sleep for 0 second/s.
# 711
# I will sleep for 0 second/s.
# 712
# I will sleep for 1 second/s.
# 713
# I will sleep for 1 second/s.
# 714
# I will sleep for 0 second/s.
# 715
# I will sleep for 1 second/s.
# 716
# I will sleep for 0 second/s.
# 717
# I will sleep for 0 second/s.
# 718
# I will sleep for 1 second/s.
# 719
# I will sleep for 0 second/s.
# 720
# I will sleep for 0 second/s.
# 721
# I will sleep for 1 second/s.
# 722
# I will sleep for 0 second/s.
# 723
# I will sleep for 0 second/s.
# 724
# I will sleep for 0 second/s.
# 725
# I will sleep for 0 second/s.
# 726
# I will sleep for 1 second/s.
# 727
# I will sleep for 0 second/s.
# 728
# I will sleep for 0 second/s.
# 729
# I will sleep for 1 second/s.
# 730
# I will sleep for 1 second/s.
# 731
# I will sleep for 1 second/s.
# 732
# I will sleep for 0 second/s.
# 733
# I will sleep for 0 second/s.
# 734
# I will sleep for 1 second/s.
# 735
# I will sleep for 1 second/s.
# 736
# I will sleep for 1 second/s.
# 737
# I will sleep for 1 second/s.
# 738
# I will sleep for 0 second/s.
# 739
# I will sleep for 1 second/s.
# 740
# I will sleep for 1 second/s.
# 741
# I will sleep for 0 second/s.
# 742
# I will sleep for 0 second/s.
# 743
# I will sleep for 1 second/s.
# 744
# I will sleep for 0 second/s.
# 745
# I will sleep for 1 second/s.
# 746
# I will sleep for 1 second/s.
# 747
# I will sleep for 0 second/s.
# 748
# I will sleep for 0 second/s.
# 749
# I will sleep for 0 second/s.
# 750
# I will sleep for 0 second/s.
# 751
# I will sleep for 1 second/s.
# 752
# I will sleep for 0 second/s.
# 753
# I will sleep for 0 second/s.
# 754
# I will sleep for 1 second/s.
# 755
# I will sleep for 1 second/s.
# 756
# I will sleep for 1 second/s.
# 757
# I will sleep for 0 second/s.
# 758
# I will sleep for 0 second/s.
# 759
# I will sleep for 0 second/s.
# 760
# I will sleep for 1 second/s.
# 761
# I will sleep for 1 second/s.
# 762
# I will sleep for 1 second/s.
# 763
# I will sleep for 0 second/s.
# 764
# I will sleep for 1 second/s.
# 765
# I will sleep for 1 second/s.
# 766
# I will sleep for 1 second/s.
# 767
# I will sleep for 1 second/s.
# 768
# I will sleep for 1 second/s.
# 769
# I will sleep for 0 second/s.
# 770
# I will sleep for 0 second/s.
# 771
# I will sleep for 1 second/s.
# 772
# I will sleep for 0 second/s.
# 773
# I will sleep for 1 second/s.
# 774
# I will sleep for 0 second/s.
# 775
# I will sleep for 1 second/s.
# 776
# I will sleep for 0 second/s.
# 777
# I will sleep for 1 second/s.
# 778
# I will sleep for 0 second/s.
# 779
# I will sleep for 0 second/s.
# 780
# I will sleep for 1 second/s.
# 781
# I will sleep for 0 second/s.
# 782
# I will sleep for 0 second/s.
# 783
# I will sleep for 0 second/s.
# 784
# I will sleep for 1 second/s.
# 785
# I will sleep for 1 second/s.
# 786
# I will sleep for 0 second/s.
# 787
# I will sleep for 0 second/s.
# 788
# I will sleep for 1 second/s.
# 789
# I will sleep for 1 second/s.
# 790
# I will sleep for 0 second/s.
# 791
# I will sleep for 1 second/s.
# 792
# I will sleep for 1 second/s.
# 793
# I will sleep for 0 second/s.
# 794
# I will sleep for 1 second/s.
# 795
# I will sleep for 1 second/s.
# 796
# I will sleep for 0 second/s.
# 797
# I will sleep for 0 second/s.
# 798
# I will sleep for 1 second/s.
# 799
# I will sleep for 0 second/s.
# 800
# I will sleep for 0 second/s.
# 801
# I will sleep for 0 second/s.
# 802
# I will sleep for 1 second/s.
# 803
# I will sleep for 0 second/s.
# 804
# I will sleep for 0 second/s.
# 805
# I will sleep for 1 second/s.
# 806
# I will sleep for 0 second/s.
# 807
# I will sleep for 1 second/s.
# 808
# I will sleep for 0 second/s.
# 809
# I will sleep for 0 second/s.
# 810
# I will sleep for 1 second/s.
# 811
# I will sleep for 0 second/s.
# 812
# I will sleep for 0 second/s.
# 813
# I will sleep for 1 second/s.
# 814
# I will sleep for 1 second/s.
# 815
# I will sleep for 0 second/s.
# 816
# I will sleep for 0 second/s.
# 817
# I will sleep for 1 second/s.
# 818
# I will sleep for 0 second/s.
# 819
# I will sleep for 1 second/s.
# 820
# I will sleep for 0 second/s.
# 821
# I will sleep for 0 second/s.
# 822
# I will sleep for 0 second/s.
# 823
# I will sleep for 0 second/s.
# 824
# I will sleep for 1 second/s.
# 825
# I will sleep for 1 second/s.
# 826
# I will sleep for 0 second/s.
# 827
# I will sleep for 0 second/s.
# 828
# I will sleep for 0 second/s.
# 829
# I will sleep for 0 second/s.
# 830
# I will sleep for 1 second/s.
# 831
# I will sleep for 1 second/s.
# 832
# I will sleep for 1 second/s.
# 833
# I will sleep for 1 second/s.
# 834
# I will sleep for 1 second/s.
# 835
# I will sleep for 1 second/s.
# 836
# I will sleep for 1 second/s.
# 837
# I will sleep for 0 second/s.
# 838
# I will sleep for 1 second/s.
# 839
# I will sleep for 1 second/s.
# 840
# I will sleep for 1 second/s.
# 841
# I will sleep for 1 second/s.
# 842
# I will sleep for 1 second/s.
# 843
# I will sleep for 1 second/s.
# 844
# I will sleep for 0 second/s.
# 845
# I will sleep for 0 second/s.
# 846
# I will sleep for 0 second/s.
# 847
# I will sleep for 0 second/s.
# 848
# I will sleep for 1 second/s.
# 849
# I will sleep for 0 second/s.
# 850
# I will sleep for 1 second/s.
# 851
# I will sleep for 1 second/s.
# 852
# I will sleep for 0 second/s.
# 853
# I will sleep for 1 second/s.
# 854
# I will sleep for 1 second/s.
# 855
# I will sleep for 1 second/s.
# 856
# I will sleep for 0 second/s.
# 857
# I will sleep for 1 second/s.
# 858
# I will sleep for 0 second/s.
# 859
# I will sleep for 0 second/s.
# 860
# I will sleep for 0 second/s.
# 861
# I will sleep for 0 second/s.
# 862
# I will sleep for 0 second/s.
# 863
# I will sleep for 0 second/s.
# 864
# I will sleep for 0 second/s.
# 865
# I will sleep for 0 second/s.
# 866
# I will sleep for 0 second/s.
# 867
# I will sleep for 1 second/s.
# 868
# I will sleep for 0 second/s.
# 869
# I will sleep for 1 second/s.
# 870
# I will sleep for 0 second/s.
# 871
# I will sleep for 0 second/s.
# 872
# I will sleep for 0 second/s.
# 873
# I will sleep for 0 second/s.
# 874
# I will sleep for 1 second/s.
# 875
# I will sleep for 1 second/s.
# 876
# I will sleep for 0 second/s.
# 877
# I will sleep for 1 second/s.
# 878
# I will sleep for 1 second/s.
# 879
# I will sleep for 0 second/s.
# 880
# I will sleep for 0 second/s.
# 881
# I will sleep for 0 second/s.
# 882
# I will sleep for 1 second/s.
# 883
# I will sleep for 1 second/s.
# 884
# I will sleep for 1 second/s.
# 885
# I will sleep for 0 second/s.
# 886
# I will sleep for 1 second/s.
# 887
# I will sleep for 1 second/s.
# 888
# I will sleep for 0 second/s.
# 889
# I will sleep for 0 second/s.
# 890
# I will sleep for 0 second/s.
# 891
# I will sleep for 0 second/s.
# 892
# I will sleep for 0 second/s.
# 893
# I will sleep for 1 second/s.
# 894
# I will sleep for 0 second/s.
# 895
# I will sleep for 1 second/s.
# 896
# I will sleep for 0 second/s.
# 897
# I will sleep for 1 second/s.
# 898
# I will sleep for 1 second/s.
# 899
# I will sleep for 0 second/s.
# 900
# I will sleep for 0 second/s.
# 901
# I will sleep for 0 second/s.
# 902
# I will sleep for 1 second/s.
# 903
# I will sleep for 0 second/s.
# 904
# I will sleep for 1 second/s.
# 905
# I will sleep for 0 second/s.
# 906
# I will sleep for 1 second/s.
# 907
# I will sleep for 1 second/s.
# 908
# I will sleep for 0 second/s.
# 909
# I will sleep for 0 second/s.
# 910
# I will sleep for 1 second/s.
# 911
# I will sleep for 0 second/s.
# 912
# I will sleep for 1 second/s.
# 913
# I will sleep for 1 second/s.
# 914
# I will sleep for 1 second/s.
# 915
# I will sleep for 0 second/s.
# 916
# I will sleep for 1 second/s.
# 917
# I will sleep for 0 second/s.
# 918
# I will sleep for 1 second/s.
# 919
# I will sleep for 1 second/s.
# 920
# I will sleep for 1 second/s.
# 921
# I will sleep for 1 second/s.
# 922
# I will sleep for 1 second/s.
# 923
# I will sleep for 0 second/s.
# 924
# I will sleep for 0 second/s.
# 925
# I will sleep for 1 second/s.
# 926
# I will sleep for 1 second/s.
# 927
# I will sleep for 1 second/s.
# 928
# I will sleep for 0 second/s.
# 929
# I will sleep for 1 second/s.
# 930
# I will sleep for 0 second/s.
# 931
# I will sleep for 0 second/s.
# 932
# I will sleep for 1 second/s.
# 933
# I will sleep for 1 second/s.
# 934
# I will sleep for 1 second/s.
# 935
# I will sleep for 1 second/s.
# 936
# I will sleep for 1 second/s.
# 937
# I will sleep for 0 second/s.
# 938
# I will sleep for 1 second/s.
# 939
# I will sleep for 0 second/s.
# 940
# I will sleep for 1 second/s.
# 941
# I will sleep for 0 second/s.
# 942
# I will sleep for 0 second/s.
# 943
# I will sleep for 1 second/s.
# 944
# I will sleep for 0 second/s.
# 945
# I will sleep for 0 second/s.
# 946
# I will sleep for 0 second/s.
# 947
# I will sleep for 0 second/s.
# 948
# I will sleep for 0 second/s.
# 949
# I will sleep for 0 second/s.
# 950
# I will sleep for 1 second/s.
# 951
# I will sleep for 1 second/s.
# 952
# I will sleep for 1 second/s.
# 953
# I will sleep for 1 second/s.
# 954
# I will sleep for 0 second/s.
# 955
# I will sleep for 1 second/s.
# 956
# I will sleep for 0 second/s.
# 957
# I will sleep for 1 second/s.
# 958
# I will sleep for 0 second/s.
# 959
# I will sleep for 0 second/s.
# 960
# I will sleep for 0 second/s.
# 961
# I will sleep for 1 second/s.
# 962
# I will sleep for 0 second/s.
# 963
# I will sleep for 0 second/s.
# 964
# I will sleep for 0 second/s.
# 965
# I will sleep for 1 second/s.
# 966
# I will sleep for 0 second/s.
# 967
# I will sleep for 1 second/s.
# 968
# I will sleep for 1 second/s.
# 969
# I will sleep for 0 second/s.
# 970
# I will sleep for 1 second/s.
# 971
# I will sleep for 1 second/s.
# 972
# I will sleep for 1 second/s.
# 973
# I will sleep for 0 second/s.
# 974
# I will sleep for 0 second/s.
# 975
# I will sleep for 1 second/s.
# 976
# I will sleep for 1 second/s.
# 977
# I will sleep for 1 second/s.
# 978
# I will sleep for 0 second/s.
# 979
# I will sleep for 1 second/s.
# 980
# I will sleep for 0 second/s.
# 981
# I will sleep for 1 second/s.
# 982
# I will sleep for 1 second/s.
# 983
# I will sleep for 1 second/s.
# 984
# I will sleep for 0 second/s.
# 985
# I will sleep for 1 second/s.
# 986
# I will sleep for 1 second/s.
# 987
# I will sleep for 0 second/s.
# 988
# I will sleep for 0 second/s.
# 989
# I will sleep for 1 second/s.
# 990
# I will sleep for 0 second/s.
# 991
# I will sleep for 1 second/s.
# 992
# I will sleep for 1 second/s.
# 993
# I will sleep for 1 second/s.
# 994
# I will sleep for 1 second/s.
# 995
# I will sleep for 1 second/s.
# 996
# I will sleep for 0 second/s.
# 997
# I will sleep for 1 second/s.
# 998
# I will sleep for 0 second/s.
# 999
# I will sleep for 1 second/s.
# 1000
# I will sleep for 1 second/s.
# 1001
# I will sleep for 1 second/s.
# 1002
# I will sleep for 0 second/s.
# 1003
# I will sleep for 1 second/s.
# 1004
# I will sleep for 1 second/s.
# 1005
# I will sleep for 0 second/s.
# 1006
# I will sleep for 1 second/s.
# 1007
# I will sleep for 0 second/s.
# 1008
# I will sleep for 1 second/s.
# 1009
# I will sleep for 1 second/s.
# 1010
# I will sleep for 1 second/s.
# 1011
# I will sleep for 1 second/s.
# 1012
# I will sleep for 1 second/s.
# 1013
# I will sleep for 0 second/s.
# 1014
# I will sleep for 1 second/s.
# 1015
# I will sleep for 0 second/s.
# 1016
# I will sleep for 0 second/s.
# 1017
# I will sleep for 1 second/s.
# 1018
# I will sleep for 1 second/s.
# 1019
# I will sleep for 0 second/s.
# 1020
# I will sleep for 0 second/s.
# 1021
# I will sleep for 0 second/s.
# 1022
# I will sleep for 1 second/s.
# 1023
# I will sleep for 1 second/s.
# 1024
# I will sleep for 0 second/s.
# 1025
# I will sleep for 0 second/s.
# 1026
# I will sleep for 0 second/s.
# 1027
# I will sleep for 0 second/s.
# 1028
# I will sleep for 1 second/s.
# 1029
# I will sleep for 0 second/s.
# 1030
# I will sleep for 0 second/s.
# 1031
# I will sleep for 1 second/s.
# 1032
# I will sleep for 0 second/s.
# 1033
# I will sleep for 1 second/s.
# 1034
# I will sleep for 1 second/s.
# 1035
# I will sleep for 0 second/s.
# 1036
# I will sleep for 1 second/s.
# 1037
# I will sleep for 1 second/s.
# 1038
# I will sleep for 1 second/s.
# 1039
# I will sleep for 1 second/s.
# 1040
# I will sleep for 0 second/s.
# 1041
# I will sleep for 0 second/s.
# 1042
# I will sleep for 1 second/s.
# 1043
# I will sleep for 0 second/s.
# 1044
# I will sleep for 0 second/s.
# 1045
# I will sleep for 0 second/s.
# 1046
# I will sleep for 0 second/s.
# 1047
# I will sleep for 1 second/s.
# 1048
# I will sleep for 0 second/s.
# 1049
# I will sleep for 1 second/s.
# 1050
# I will sleep for 0 second/s.
# 1051
# I will sleep for 0 second/s.
# 1052
# I will sleep for 1 second/s.
# 1053
# I will sleep for 0 second/s.
# 1054
# I will sleep for 1 second/s.
# 1055
# I will sleep for 1 second/s.
# 1056
# I will sleep for 0 second/s.
# 1057
# I will sleep for 1 second/s.
# 1058
# I will sleep for 1 second/s.
# 1059
# I will sleep for 1 second/s.
# 1060
# I will sleep for 1 second/s.
# 1061
# I will sleep for 1 second/s.
# 1062
# I will sleep for 1 second/s.
# 1063
# I will sleep for 0 second/s.
# 1064
# I will sleep for 1 second/s.
# 1065
# I will sleep for 0 second/s.
# 1066
# I will sleep for 0 second/s.
# 1067
# I will sleep for 0 second/s.
# 1068
# I will sleep for 0 second/s.
# 1069
# I will sleep for 1 second/s.
# 1070
# I will sleep for 1 second/s.
# 1071
# I will sleep for 0 second/s.
# 1072
# I will sleep for 1 second/s.
# 1073
# I will sleep for 0 second/s.
# 1074
# I will sleep for 0 second/s.
# 1075
# I will sleep for 1 second/s.
# 1076
# I will sleep for 0 second/s.
# 1077
# I will sleep for 1 second/s.
# 1078
# I will sleep for 0 second/s.
# 1079
# I will sleep for 1 second/s.
# 1080
# I will sleep for 1 second/s.
# 1081
# I will sleep for 1 second/s.
# 1082
# I will sleep for 0 second/s.
# 1083
# I will sleep for 0 second/s.
# 1084
# I will sleep for 1 second/s.
# 1085
# I will sleep for 0 second/s.
# 1086
# I will sleep for 1 second/s.
# 1087
# I will sleep for 1 second/s.
# 1088
# I will sleep for 1 second/s.
# 1089
# I will sleep for 1 second/s.
# 1090
# I will sleep for 0 second/s.
# 1091
# I will sleep for 1 second/s.
# 1092
# I will sleep for 1 second/s.
# 1093
# I will sleep for 0 second/s.
# 1094
# I will sleep for 1 second/s.
# 1095
# I will sleep for 0 second/s.
# 1096
# I will sleep for 0 second/s.
# 1097
# I will sleep for 0 second/s.
# 1098
# I will sleep for 1 second/s.
# 1099
# I will sleep for 1 second/s.
# 1100
# I will sleep for 1 second/s.
# 1101
# I will sleep for 1 second/s.
# 1102
# I will sleep for 0 second/s.
# 1103
# I will sleep for 1 second/s.
# 1104
# I will sleep for 1 second/s.
# 1105
# I will sleep for 1 second/s.
# 1106
# I will sleep for 1 second/s.
# 1107
# I will sleep for 0 second/s.
# 1108
# I will sleep for 0 second/s.
# 1109
# I will sleep for 0 second/s.
# 1110
# I will sleep for 0 second/s.
# 1111
# I will sleep for 1 second/s.
# 1112
# I will sleep for 0 second/s.
# 1113
# I will sleep for 0 second/s.
# 1114
# I will sleep for 0 second/s.
# 1115
# I will sleep for 1 second/s.
# 1116
# I will sleep for 0 second/s.
# 1117
# I will sleep for 1 second/s.
# 1118
# I will sleep for 0 second/s.
# 1119
# I will sleep for 1 second/s.
# 1120
# I will sleep for 0 second/s.
# 1121
# I will sleep for 0 second/s.
# 1122
# I will sleep for 0 second/s.
# 1123
# I will sleep for 0 second/s.
# 1124
# I will sleep for 1 second/s.
# 1125
# I will sleep for 1 second/s.
# 1126
# I will sleep for 1 second/s.
# 1127
# I will sleep for 0 second/s.
# 1128
# I will sleep for 0 second/s.
# 1129
# I will sleep for 0 second/s.
# 1130
# I will sleep for 1 second/s.
# 1131
# I will sleep for 0 second/s.
# 1132
# I will sleep for 0 second/s.
# 1133
# I will sleep for 1 second/s.
# 1134
# I will sleep for 1 second/s.
# 1135
# I will sleep for 1 second/s.
# 1136
# I will sleep for 0 second/s.
# 1137
# I will sleep for 1 second/s.
# 1138
# I will sleep for 0 second/s.
# 1139
# I will sleep for 0 second/s.
# 1140
# I will sleep for 1 second/s.
# 1141
# I will sleep for 0 second/s.
# 1142
# I will sleep for 0 second/s.
# 1143
# I will sleep for 0 second/s.
# 1144
# I will sleep for 0 second/s.
# 1145
# I will sleep for 1 second/s.
# 1146
# I will sleep for 1 second/s.
# 1147
# I will sleep for 0 second/s.
# 1148
# I will sleep for 1 second/s.
# 1149
# I will sleep for 1 second/s.
# 1150
# I will sleep for 1 second/s.
# 1151
# I will sleep for 0 second/s.
# 1152
# I will sleep for 0 second/s.
# 1153
# I will sleep for 0 second/s.
# 1154
# I will sleep for 0 second/s.
# 1155
# I will sleep for 0 second/s.
# 1156
# I will sleep for 0 second/s.
# 1157
# I will sleep for 0 second/s.
# 1158
# I will sleep for 0 second/s.
# 1159
# I will sleep for 1 second/s.
# 1160
# I will sleep for 0 second/s.
# 1161
# I will sleep for 0 second/s.
# 1162
# I will sleep for 1 second/s.
# 1163
# I will sleep for 1 second/s.
# 1164
# I will sleep for 1 second/s.
# 1165
# I will sleep for 0 second/s.
# 1166
# I will sleep for 1 second/s.
# 1167
# I will sleep for 0 second/s.
# 1168
# I will sleep for 0 second/s.
# 1169
# I will sleep for 0 second/s.
# 1170
# I will sleep for 0 second/s.
# 1171
# I will sleep for 0 second/s.
# 1172
# I will sleep for 0 second/s.
# 1173
# I will sleep for 0 second/s.
# 1174
# I will sleep for 0 second/s.
# 1175
# I will sleep for 0 second/s.
# 1176
# I will sleep for 0 second/s.
# 1177
# I will sleep for 1 second/s.
# 1178
# I will sleep for 1 second/s.
# 1179
# I will sleep for 1 second/s.
# 1180
# I will sleep for 1 second/s.
# 1181
# I will sleep for 1 second/s.
# 1182
# I will sleep for 1 second/s.
# 1183
# I will sleep for 0 second/s.
# 1184
# I will sleep for 0 second/s.
# 1185
# I will sleep for 0 second/s.
# 1186
# I will sleep for 0 second/s.
# 1187
# I will sleep for 1 second/s.
# 1188
# I will sleep for 0 second/s.
# 1189
# I will sleep for 1 second/s.
# 1190
# I will sleep for 0 second/s.
# 1191
# I will sleep for 0 second/s.
# 1192
# I will sleep for 0 second/s.
# 1193
# I will sleep for 1 second/s.
# 1194
# I will sleep for 1 second/s.
# 1195
# I will sleep for 0 second/s.
# 1196
# I will sleep for 1 second/s.
# 1197
# I will sleep for 1 second/s.
# 1198
# I will sleep for 1 second/s.
# 1199
# I will sleep for 1 second/s.
# 1200
# I will sleep for 0 second/s.
# 1201
# I will sleep for 0 second/s.
# 1202
# I will sleep for 1 second/s.
# 1203
# I will sleep for 1 second/s.
# 1204
# I will sleep for 0 second/s.
# 1205
# I will sleep for 0 second/s.
# 1206
# I will sleep for 1 second/s.
# 1207
# I will sleep for 0 second/s.
# 1208
# I will sleep for 1 second/s.
# 1209
# I will sleep for 1 second/s.
# 1210
# I will sleep for 1 second/s.
# 1211
# I will sleep for 1 second/s.
# 1212
# I will sleep for 0 second/s.
# 1213
# I will sleep for 0 second/s.
# 1214
# I will sleep for 0 second/s.
# 1215
# I will sleep for 1 second/s.
# 1216
# I will sleep for 1 second/s.
# 1217
# I will sleep for 1 second/s.
# 1218
# I will sleep for 0 second/s.
# 1219
# I will sleep for 1 second/s.
# 1220
# I will sleep for 0 second/s.
# 1221
# I will sleep for 1 second/s.
# 1222
# I will sleep for 1 second/s.
# 1223
# I will sleep for 1 second/s.
# 1224
# I will sleep for 1 second/s.
# 1225
# I will sleep for 1 second/s.
# 1226
# I will sleep for 0 second/s.
# 1227
# I will sleep for 0 second/s.
# 1228
# I will sleep for 0 second/s.
# 1229
# I will sleep for 0 second/s.
# 1230
# I will sleep for 1 second/s.
# 1231
# I will sleep for 0 second/s.
# 1232
# I will sleep for 1 second/s.
# 1233
# I will sleep for 1 second/s.
# 1234
# I will sleep for 0 second/s.
# 1235
# I will sleep for 0 second/s.
# 1236
# I will sleep for 0 second/s.
# 1237
# I will sleep for 1 second/s.
# 1238
# I will sleep for 1 second/s.
# 1239
# I will sleep for 0 second/s.
# 1240
# I will sleep for 0 second/s.
# 1241
# I will sleep for 1 second/s.
# 1242
# I will sleep for 1 second/s.
# 1243
# I will sleep for 1 second/s.
# 1244
# I will sleep for 0 second/s.
# 1245
# I will sleep for 1 second/s.
# 1246
# I will sleep for 1 second/s.
# 1247
# I will sleep for 1 second/s.
# 1248
# I will sleep for 0 second/s.
# 1249
# I will sleep for 0 second/s.
# 1250
# I will sleep for 0 second/s.
# 1251
# I will sleep for 1 second/s.
# 1252
# I will sleep for 1 second/s.
# 1253
# I will sleep for 1 second/s.
# 1254
# I will sleep for 1 second/s.
# 1255
# I will sleep for 1 second/s.
# 1256
# I will sleep for 1 second/s.
# 1257
# I will sleep for 1 second/s.
# 1258
# I will sleep for 1 second/s.
# 1259
# I will sleep for 1 second/s.
# 1260
# I will sleep for 0 second/s.
# 1261
# I will sleep for 1 second/s.
# 1262
# I will sleep for 0 second/s.
# 1263
# I will sleep for 0 second/s.
# 1264
# I will sleep for 0 second/s.
# 1265
# I will sleep for 1 second/s.
# 1266
# I will sleep for 0 second/s.
# 1267
# I will sleep for 1 second/s.
# 1268
# I will sleep for 1 second/s.
# 1269
# I will sleep for 0 second/s.
# 1270
# I will sleep for 0 second/s.
# 1271
# I will sleep for 0 second/s.
# 1272
# I will sleep for 0 second/s.
# 1273
# I will sleep for 1 second/s.
# 1274
# I will sleep for 0 second/s.
# 1275
# I will sleep for 0 second/s.
# 1276
# I will sleep for 0 second/s.
# 1277
# I will sleep for 0 second/s.
# 1278
# I will sleep for 0 second/s.
# 1279
# I will sleep for 1 second/s.
# 1280
# I will sleep for 1 second/s.
# 1281
# I will sleep for 1 second/s.
# 1282
# I will sleep for 1 second/s.
# 1283
# I will sleep for 1 second/s.
# 1284
# I will sleep for 1 second/s.
# 1285
# I will sleep for 0 second/s.
# 1286
# I will sleep for 1 second/s.
# 1287
# I will sleep for 1 second/s.
# 1288
# I will sleep for 0 second/s.
# 1289
# I will sleep for 1 second/s.
# 1290
# I will sleep for 1 second/s.
# 1291
# I will sleep for 1 second/s.
# 1292
# I will sleep for 1 second/s.
# 1293
# I will sleep for 0 second/s.
# 1294
# I will sleep for 1 second/s.
# 1295
# I will sleep for 0 second/s.
# 1296
# I will sleep for 0 second/s.
# 1297
# I will sleep for 1 second/s.
# 1298
# I will sleep for 0 second/s.
# 1299
# I will sleep for 0 second/s.
# 1300
# I will sleep for 0 second/s.
# 1301
# I will sleep for 0 second/s.
# 1302
# I will sleep for 0 second/s.
# 1303
# I will sleep for 0 second/s.
# 1304
# I will sleep for 0 second/s.
# 1305
# I will sleep for 1 second/s.
# 1306
# I will sleep for 0 second/s.
# 1307
# I will sleep for 0 second/s.
# 1308
# I will sleep for 1 second/s.
# 1309
# I will sleep for 1 second/s.
# 1310
# I will sleep for 0 second/s.
# 1311
# I will sleep for 1 second/s.
# 1312
# I will sleep for 0 second/s.
# 1313
# I will sleep for 0 second/s.
# 1314
# I will sleep for 1 second/s.
# 1315
# I will sleep for 0 second/s.
# 1316
# I will sleep for 0 second/s.
# 1317
# I will sleep for 1 second/s.
# 1318
# I will sleep for 1 second/s.
# 1319
# I will sleep for 0 second/s.
# 1320
# I will sleep for 1 second/s.
# 1321
# I will sleep for 1 second/s.
# 1322
# I will sleep for 1 second/s.
# 1323
# I will sleep for 0 second/s.
# 1324
# I will sleep for 0 second/s.
# 1325
# I will sleep for 0 second/s.
# 1326
# I will sleep for 0 second/s.
# 1327
# I will sleep for 0 second/s.
# 1328
# I will sleep for 0 second/s.
# 1329
# I will sleep for 0 second/s.
# 1330
# I will sleep for 0 second/s.
# 1331
# I will sleep for 1 second/s.
# 1332
# I will sleep for 1 second/s.
# 1333
# I will sleep for 0 second/s.
# 1334
# I will sleep for 1 second/s.
# 1335
# I will sleep for 0 second/s.
# 1336
# I will sleep for 0 second/s.
# 1337
# I will sleep for 0 second/s.
# 1338
# I will sleep for 1 second/s.
# 1339
# I will sleep for 0 second/s.
# 1340
# I will sleep for 0 second/s.
# 1341
# I will sleep for 0 second/s.
# 1342
# I will sleep for 0 second/s.
# 1343
# I will sleep for 1 second/s.
# 1344
# I will sleep for 1 second/s.
# 1345
# I will sleep for 0 second/s.
# 1346
# I will sleep for 1 second/s.
# 1347
# I will sleep for 0 second/s.
# 1348
# I will sleep for 0 second/s.
# 1349
# I will sleep for 0 second/s.
# 1350
# I will sleep for 0 second/s.
# 1351
# I will sleep for 0 second/s.
# 1352
# I will sleep for 0 second/s.
# 1353
# I will sleep for 0 second/s.
# 1354
# I will sleep for 1 second/s.
# 1355
# I will sleep for 0 second/s.
# 1356
# I will sleep for 1 second/s.
# 1357
# I will sleep for 1 second/s.
# 1358
# I will sleep for 0 second/s.
# 1359
# I will sleep for 1 second/s.
# 1360
# I will sleep for 0 second/s.
# 1361
# I will sleep for 0 second/s.
# 1362
# I will sleep for 0 second/s.
# 1363
# I will sleep for 1 second/s.
# 1364
# I will sleep for 0 second/s.
# 1365
# I will sleep for 1 second/s.
# 1366
# I will sleep for 0 second/s.
# 1367
# I will sleep for 1 second/s.
# 1368
# I will sleep for 1 second/s.
# 1369
# I will sleep for 1 second/s.
# 1370
# I will sleep for 1 second/s.
# 1371
# I will sleep for 0 second/s.
# 1372
# I will sleep for 1 second/s.
# 1373
# I will sleep for 1 second/s.
# 1374
# I will sleep for 0 second/s.
# 1375
# I will sleep for 0 second/s.
# 1376
# I will sleep for 0 second/s.
# 1377
# I will sleep for 0 second/s.
# 1378
# I will sleep for 0 second/s.
# 1379
# I will sleep for 1 second/s.
# 1380
# I will sleep for 0 second/s.
# 1381
# I will sleep for 1 second/s.
# 1382
# I will sleep for 1 second/s.
# 1383
# I will sleep for 0 second/s.
# 1384
# I will sleep for 0 second/s.
# 1385
# I will sleep for 0 second/s.
# 1386
# I will sleep for 1 second/s.
# 1387
# I will sleep for 1 second/s.
# 1388
# I will sleep for 1 second/s.
# 1389
# I will sleep for 0 second/s.
# 1390
# I will sleep for 1 second/s.
# 1391
# I will sleep for 0 second/s.
# 1392
# I will sleep for 0 second/s.
# 1393
# I will sleep for 1 second/s.
# 1394
# I will sleep for 1 second/s.
# 1395
# I will sleep for 1 second/s.
# 1396
# I will sleep for 1 second/s.
# 1397
# I will sleep for 1 second/s.
# 1398
# I will sleep for 1 second/s.
# 1399
# I will sleep for 1 second/s.
# 1400
# I will sleep for 0 second/s.
# 1401
# I will sleep for 0 second/s.
# 1402
# I will sleep for 1 second/s.
# 1403
# I will sleep for 1 second/s.
# 1404
# I will sleep for 0 second/s.
# 1405
# I will sleep for 0 second/s.
# 1406
# I will sleep for 1 second/s.
# 1407
# I will sleep for 0 second/s.
# 1408
# I will sleep for 1 second/s.
# 1409
# I will sleep for 1 second/s.
# 1410
# I will sleep for 1 second/s.
# 1411
# I will sleep for 0 second/s.
# 1412
# I will sleep for 0 second/s.
# 1413
# I will sleep for 1 second/s.
# 1414
# I will sleep for 1 second/s.
# 1415
# I will sleep for 0 second/s.
# 1416
# I will sleep for 0 second/s.
# 1417
# I will sleep for 0 second/s.
# 1418
# I will sleep for 0 second/s.
# 1419
# I will sleep for 0 second/s.
# 1420
# I will sleep for 1 second/s.
# 1421
# I will sleep for 1 second/s.
# 1422
# I will sleep for 0 second/s.
# 1423
# I will sleep for 0 second/s.
# 1424
# I will sleep for 0 second/s.
# 1425
# I will sleep for 0 second/s.
# 1426
# I will sleep for 0 second/s.
# 1427
# I will sleep for 0 second/s.
# 1428
# I will sleep for 0 second/s.
# 1429
# I will sleep for 1 second/s.
# 1430
# I will sleep for 1 second/s.
# 1431
# I will sleep for 1 second/s.
# 1432
# I will sleep for 0 second/s.
# 1433
# I will sleep for 0 second/s.
# 1434
# I will sleep for 0 second/s.
# 1435
# I will sleep for 0 second/s.
# 1436
# I will sleep for 0 second/s.
# 1437
# I will sleep for 0 second/s.
# 1438
# I will sleep for 0 second/s.
# 1439
# I will sleep for 0 second/s.
# 1440
# I will sleep for 0 second/s.
# 1441
# I will sleep for 0 second/s.
# 1442
# I will sleep for 1 second/s.
# 1443
# I will sleep for 0 second/s.
# 1444
# I will sleep for 1 second/s.
# 1445
# I will sleep for 0 second/s.
# 1446
# I will sleep for 1 second/s.
# 1447
# I will sleep for 0 second/s.
# 1448
# I will sleep for 0 second/s.
# 1449
# I will sleep for 0 second/s.
# 1450
# I will sleep for 1 second/s.
# 1451
# I will sleep for 0 second/s.
# 1452
# I will sleep for 1 second/s.
# 1453
# I will sleep for 1 second/s.
# 1454
# I will sleep for 1 second/s.
# 1455
# I will sleep for 0 second/s.
# 1456
# I will sleep for 0 second/s.
# 1457
# I will sleep for 0 second/s.
# 1458
# I will sleep for 1 second/s.
# 1459
# I will sleep for 1 second/s.
# 1460
# I will sleep for 0 second/s.
# 1461
# I will sleep for 0 second/s.
# 1462
# I will sleep for 0 second/s.
# 1463
# I will sleep for 0 second/s.
# 1464
# I will sleep for 0 second/s.
# 1465
# I will sleep for 0 second/s.
# 1466
# I will sleep for 0 second/s.
# 1467
# I will sleep for 0 second/s.
# 1468
# I will sleep for 1 second/s.
# 1469
# I will sleep for 1 second/s.
# 1470
# I will sleep for 1 second/s.
# 1471
# I will sleep for 1 second/s.
# 1472
# I will sleep for 0 second/s.
# 1473
# I will sleep for 0 second/s.
# 1474
# I will sleep for 1 second/s.
# 1475
# I will sleep for 0 second/s.
# 1476
# I will sleep for 1 second/s.
# 1477
# I will sleep for 1 second/s.
# 1478
# I will sleep for 1 second/s.
# 1479
# I will sleep for 0 second/s.
# 1480
# I will sleep for 0 second/s.
# 1481
# I will sleep for 1 second/s.
# 1482
# I will sleep for 0 second/s.
# 1483
# I will sleep for 1 second/s.
# 1484
# I will sleep for 1 second/s.
# 1485
# I will sleep for 1 second/s.
# 1486
# I will sleep for 1 second/s.
# 1487
# I will sleep for 1 second/s.
# 1488
# I will sleep for 1 second/s.
# 1489
# I will sleep for 0 second/s.
# 1490
# I will sleep for 0 second/s.
# 1491
# I will sleep for 0 second/s.
# 1492
# I will sleep for 0 second/s.
# 1493
# I will sleep for 0 second/s.
# 1494
# I will sleep for 0 second/s.
# 1495
# I will sleep for 1 second/s.
# 1496
# I will sleep for 0 second/s.
# 1497
# I will sleep for 0 second/s.
# 1498
# I will sleep for 1 second/s.
# 1499
# I will sleep for 0 second/s.
# 1500
# I will sleep for 1 second/s.
# 1501
# I will sleep for 1 second/s.
# 1502
# I will sleep for 0 second/s.
# 1503
# I will sleep for 1 second/s.
# 1504
# I will sleep for 0 second/s.
# 1505
# I will sleep for 0 second/s.
# 1506
# I will sleep for 1 second/s.
# 1507
# I will sleep for 0 second/s.
# 1508
# I will sleep for 1 second/s.
# 1509
# I will sleep for 0 second/s.
# 1510
# I will sleep for 0 second/s.
# 1511
# I will sleep for 0 second/s.
# 1512
# I will sleep for 1 second/s.
# 1513
# I will sleep for 1 second/s.
# 1514
# I will sleep for 1 second/s.
# 1515
# I will sleep for 1 second/s.
# 1516
# I will sleep for 1 second/s.
# 1517
# I will sleep for 1 second/s.
# 1518
# I will sleep for 1 second/s.
# 1519
# I will sleep for 0 second/s.
# 1520
# I will sleep for 1 second/s.
# 1521
# I will sleep for 0 second/s.
# 1522
# I will sleep for 1 second/s.
# 1523
# I will sleep for 0 second/s.
# 1524
# I will sleep for 1 second/s.
# 1525
# I will sleep for 0 second/s.
# 1526
# I will sleep for 0 second/s.
# 1527
# I will sleep for 0 second/s.
# 1528
# I will sleep for 1 second/s.
# 1529
# I will sleep for 1 second/s.
# 1530
# I will sleep for 1 second/s.
# 1531
# I will sleep for 1 second/s.
# 1532
# I will sleep for 0 second/s.
# 1533
# I will sleep for 0 second/s.
# 1534
# I will sleep for 0 second/s.
# 1535
# I will sleep for 0 second/s.
# 1536
# I will sleep for 0 second/s.
# 1537
# I will sleep for 0 second/s.
# 1538
# I will sleep for 0 second/s.
# 1539
# I will sleep for 0 second/s.
# 1540
# I will sleep for 0 second/s.
# 1541
# I will sleep for 0 second/s.
# 1542
# I will sleep for 1 second/s.
# 1543
# I will sleep for 1 second/s.
# 1544
# I will sleep for 0 second/s.
# 1545
# I will sleep for 1 second/s.
# 1546
# I will sleep for 0 second/s.
# 1547
# I will sleep for 1 second/s.
# 1548
# I will sleep for 1 second/s.
# 1549
# I will sleep for 1 second/s.
# 1550
# I will sleep for 0 second/s.
# 1551
# I will sleep for 1 second/s.
# 1552
# I will sleep for 1 second/s.
# 1553
# I will sleep for 1 second/s.
# 1554
# I will sleep for 0 second/s.
# 1555
# I will sleep for 1 second/s.
# 1556
# I will sleep for 0 second/s.
# 1557
# I will sleep for 1 second/s.
# 1558
# I will sleep for 0 second/s.
# 1559
# I will sleep for 0 second/s.
# 1560
# I will sleep for 0 second/s.
# 1561
# I will sleep for 1 second/s.
# 1562
# I will sleep for 0 second/s.
# 1563
# I will sleep for 1 second/s.
# 1564
# I will sleep for 1 second/s.
# 1565
# I will sleep for 1 second/s.
# 1566
# I will sleep for 1 second/s.
# 1567
# I will sleep for 1 second/s.
# 1568
# I will sleep for 0 second/s.
# 1569
# I will sleep for 1 second/s.
# 1570
# I will sleep for 1 second/s.
# 1571
# I will sleep for 1 second/s.
# 1572
# I will sleep for 0 second/s.
# 1573
# I will sleep for 1 second/s.
# 1574
# I will sleep for 0 second/s.
# 1575
# I will sleep for 1 second/s.
# 1576
# I will sleep for 0 second/s.
# 1577
# I will sleep for 0 second/s.
# 1578
# I will sleep for 0 second/s.
# 1579
# I will sleep for 1 second/s.
# 1580
# I will sleep for 1 second/s.
# 1581
# I will sleep for 1 second/s.
# 1582
# I will sleep for 1 second/s.
# 1583
# I will sleep for 1 second/s.
# 1584
# I will sleep for 1 second/s.
# 1585
# I will sleep for 1 second/s.
# 1586
# I will sleep for 1 second/s.
# 1587
# I will sleep for 0 second/s.
# 1588
# I will sleep for 1 second/s.
# 1589
# I will sleep for 1 second/s.
# 1590
# I will sleep for 1 second/s.
# 1591
# I will sleep for 1 second/s.
# 1592
# I will sleep for 1 second/s.
# 1593
# I will sleep for 1 second/s.
# 1594
# I will sleep for 1 second/s.
# 1595
# I will sleep for 1 second/s.
# 1596
# I will sleep for 1 second/s.
# 1597
# I will sleep for 1 second/s.
# 1598
# I will sleep for 1 second/s.
# 1599
# I will sleep for 1 second/s.
# 1600
# I will sleep for 0 second/s.
# 1601
# I will sleep for 0 second/s.
# 1602
# I will sleep for 1 second/s.
# 1603
# I will sleep for 1 second/s.
# 1604
# I will sleep for 1 second/s.
# 1605
# I will sleep for 1 second/s.
# 1606
# I will sleep for 1 second/s.
# 1607
# I will sleep for 1 second/s.
# 1608
# I will sleep for 1 second/s.
# 1609
# I will sleep for 1 second/s.
# 1610
# I will sleep for 0 second/s.
# 1611
# I will sleep for 1 second/s.
# 1612
# I will sleep for 1 second/s.
# 1613
# I will sleep for 0 second/s.
# 1614
# I will sleep for 1 second/s.
# 1615
# I will sleep for 0 second/s.
# 1616
# I will sleep for 1 second/s.
# 1617
# I will sleep for 0 second/s.
# 1618
# I will sleep for 0 second/s.
# 1619
# I will sleep for 0 second/s.
# 1620
# I will sleep for 0 second/s.
# 1621
# I will sleep for 1 second/s.
# 1622
# I will sleep for 1 second/s.
# 1623
# I will sleep for 0 second/s.
# 1624
# I will sleep for 0 second/s.
# 1625
# I will sleep for 1 second/s.
# 1626
# I will sleep for 1 second/s.
# 1627
# I will sleep for 1 second/s.
# 1628
# I will sleep for 1 second/s.
# 1629
# I will sleep for 1 second/s.
# 1630
# I will sleep for 0 second/s.
# 1631
# I will sleep for 0 second/s.
# 1632
# I will sleep for 0 second/s.
# 1633
# I will sleep for 0 second/s.
# 1634
# I will sleep for 1 second/s.
# 1635
# I will sleep for 0 second/s.
# 1636
# I will sleep for 0 second/s.
# 1637
# I will sleep for 1 second/s.
# 1638
# I will sleep for 1 second/s.
# 1639
# I will sleep for 0 second/s.
# 1640
# I will sleep for 0 second/s.
# 1641
# I will sleep for 1 second/s.
# 1642
# I will sleep for 0 second/s.
# 1643
# I will sleep for 1 second/s.
# 1644
# I will sleep for 1 second/s.
# 1645
# I will sleep for 0 second/s.
# 1646
# I will sleep for 0 second/s.
# 1647
# I will sleep for 1 second/s.
# 1648
# I will sleep for 1 second/s.
# 1649
# I will sleep for 0 second/s.
# 1650
# I will sleep for 0 second/s.
# 1651
# I will sleep for 0 second/s.
# 1652
# I will sleep for 0 second/s.
# 1653
# I will sleep for 1 second/s.
# 1654
# I will sleep for 1 second/s.
# 1655
# I will sleep for 0 second/s.
# 1656
# I will sleep for 0 second/s.
# 1657
# I will sleep for 1 second/s.
# 1658
# I will sleep for 0 second/s.
# 1659
# I will sleep for 0 second/s.
# 1660
# I will sleep for 1 second/s.
# 1661
# I will sleep for 1 second/s.
# 1662
# I will sleep for 1 second/s.
# 1663
# I will sleep for 1 second/s.
# 1664
# I will sleep for 1 second/s.
# 1665
# I will sleep for 0 second/s.
# 1666
# I will sleep for 1 second/s.
# 1667
# I will sleep for 1 second/s.
# 1668
# I will sleep for 1 second/s.
# 1669
# I will sleep for 0 second/s.
# 1670
# I will sleep for 0 second/s.
# 1671
# I will sleep for 0 second/s.
# 1672
# I will sleep for 1 second/s.
# 1673
# I will sleep for 1 second/s.
# 1674
# I will sleep for 1 second/s.
# 1675
# I will sleep for 0 second/s.
# 1676
# I will sleep for 1 second/s.
# 1677
# I will sleep for 1 second/s.
# 1678
# I will sleep for 0 second/s.
# 1679
# I will sleep for 0 second/s.
# 1680
# I will sleep for 0 second/s.
# 1681
# I will sleep for 1 second/s.
# 1682
# I will sleep for 1 second/s.
# 1683
# I will sleep for 0 second/s.
# 1684
# I will sleep for 0 second/s.
# 1685
# I will sleep for 0 second/s.
# 1686
# I will sleep for 0 second/s.
# 1687
# I will sleep for 0 second/s.
# 1688
# I will sleep for 1 second/s.
# 1689
# I will sleep for 0 second/s.
# 1690
# I will sleep for 1 second/s.
# 1691
# I will sleep for 1 second/s.
# 1692
# I will sleep for 1 second/s.
# 1693
# I will sleep for 1 second/s.
# 1694
# I will sleep for 0 second/s.
# 1695
# I will sleep for 0 second/s.
# 1696
# I will sleep for 1 second/s.
# 1697
# I will sleep for 1 second/s.
# 1698
# I will sleep for 0 second/s.
# 1699
# I will sleep for 1 second/s.
# 1700
# I will sleep for 0 second/s.
# 1701
# I will sleep for 0 second/s.
# 1702
# I will sleep for 0 second/s.
# 1703
# I will sleep for 0 second/s.
# 1704
# I will sleep for 0 second/s.
# 1705
# I will sleep for 0 second/s.
# 1706
# I will sleep for 0 second/s.
# 1707
# I will sleep for 0 second/s.
# 1708
# I will sleep for 1 second/s.
# 1709
# I will sleep for 1 second/s.
# 1710
# I will sleep for 1 second/s.
# 1711
# I will sleep for 0 second/s.
# 1712
# I will sleep for 0 second/s.
# 1713
# I will sleep for 0 second/s.
# 1714
# I will sleep for 0 second/s.
# 1715
# I will sleep for 1 second/s.
# 1716
# I will sleep for 1 second/s.
# 1717
# I will sleep for 1 second/s.
# 1718
# I will sleep for 0 second/s.
# 1719
# I will sleep for 0 second/s.
# 1720
# I will sleep for 1 second/s.
# 1721
# I will sleep for 0 second/s.
# 1722
# I will sleep for 1 second/s.
# 1723
# I will sleep for 0 second/s.
# 1724
# I will sleep for 0 second/s.
# 1725
# I will sleep for 1 second/s.
# 1726
# I will sleep for 1 second/s.
# 1727
# I will sleep for 0 second/s.
# 1728
# I will sleep for 1 second/s.
# 1729
# I will sleep for 1 second/s.
# 1730
# I will sleep for 1 second/s.
# 1731
# I will sleep for 0 second/s.
# 1732
# I will sleep for 1 second/s.
# 1733
# I will sleep for 1 second/s.
# 1734
# I will sleep for 0 second/s.
# 1735
# I will sleep for 1 second/s.
# 1736
# I will sleep for 1 second/s.
# 1737
# I will sleep for 0 second/s.
# 1738
# I will sleep for 1 second/s.
# 1739
# I will sleep for 0 second/s.
# 1740
# I will sleep for 0 second/s.
# 1741
# I will sleep for 0 second/s.
# 1742
# I will sleep for 0 second/s.
# 1743
# I will sleep for 0 second/s.
# 1744
# I will sleep for 0 second/s.
# 1745
# I will sleep for 1 second/s.
# 1746
# I will sleep for 1 second/s.
# 1747
# I will sleep for 1 second/s.
# 1748
# I will sleep for 1 second/s.
# 1749
# I will sleep for 1 second/s.
# 1750
# I will sleep for 0 second/s.
# 1751
# I will sleep for 1 second/s.
# 1752
# I will sleep for 1 second/s.
# 1753
# I will sleep for 0 second/s.
# 1754
# I will sleep for 0 second/s.
# 1755
# I will sleep for 1 second/s.
# 1756
# I will sleep for 1 second/s.
# 1757
# I will sleep for 0 second/s.
# 1758
# I will sleep for 1 second/s.
# 1759

# %%
# adding audio features to my list of songs
repository['uri']=songs_uri
repository['danceability']=songs_danceability
repository['energy']=songs_energy
repository['key']=songs_key
repository['loudness']=songs_loudness
repository['mode']=songs_mode
repository['speechiness']=songs_speechiness
repository['acousticness']=songs_acousticness
repository['instrumentalness']=songs_instrumentalness
repository['liveness']=songs_liveness
repository['valence']=songs_valence
repository['tempo']=songs_tempo
repository['duration_ms']=songs_duration_ms
repository['time_signature']=songs_time_signature

# %%
repository
# Out:
#                 artist                                song  \
# 0           pink floyd  another brick in the wall (part 2)
# 1     barbra streisand                     a woman in love
# 2          john lennon           (just like) starting over
# 3           diana ross                         upside down
# 4            lipps inc                           funkytown
# ...                ...                                 ...
# 1755            poison            every rose has its thorn
# 1756       bobby brown                      my prerogative
# 1757    gloria estefan                don't wanna lose you
# 1758     milli vanilli             girl i'm gonna miss you
# 1759   janet jackson\n                       miss you much
#
#                                        uri danceability energy key loudness  \
# 0     spotify:track:1xUTI8Ce8IQnyYCGPmrbzS        0.395  0.766   0  -11.041
# 1     spotify:track:53No4na49hTw82MxrFh2PB        0.489  0.245   3  -16.876
# 2     spotify:track:5y0YreEOnQiKFAnCrcFIXz        0.701   0.79   9    -6.16
# 3     spotify:track:3pbtBomO4Zt5gGiqsYeiBH        0.873  0.855   5   -8.559
# 4     spotify:track:5dIKF6uVJ206hj0pO0gg0I        0.893  0.509   0  -10.136
# ...                                    ...          ...    ...  ..      ...
# 1755  spotify:track:43GS3mtezoIFiuIZCLLiDY        0.533  0.637   6   -5.571
# 1756  spotify:track:0v9kGNjkKdQUdDoBIuiph4        0.762  0.625   9  -10.481
# 1757  spotify:track:4tEpvocDTdNVR9DYxnJTFy        0.545  0.356   5  -14.127
# 1758  spotify:track:1ffAMndLMFbKHpXuIDBwc1        0.754  0.453   9   -9.862
# 1759  spotify:track:4r5VaK6H1bq0cTGPMTN97Z        0.702  0.975   6   -7.968
#
#      mode speechiness acousticness instrumentalness liveness valence    tempo  \
# 0       1      0.0512      0.00583          0.00624    0.774   0.611   105.41
# 1       0      0.0284         0.43         0.000015    0.298   0.333  169.747
# 2       1      0.0725        0.301         0.000061    0.179   0.421   99.104
# 3       0      0.0615        0.179           0.0285   0.0377   0.884  107.868
# 4       1      0.0659      0.00154            0.515   0.0783   0.334  122.478
# ...   ...         ...          ...              ...      ...     ...      ...
# 1755    1      0.0323         0.16         0.000011    0.369   0.292  140.167
# 1756    1      0.0562       0.0655                0    0.252   0.696  110.163
# 1757    1      0.0245        0.413         0.000002    0.128   0.465   82.214
# 1758    1      0.0443       0.0998          0.00487    0.108   0.758  151.239
# 1759    0      0.0396       0.0305         0.000134    0.165   0.646  115.185
#
#      duration_ms time_signature
# 0         326373              4
# 1         230227              4
# 2         236547              4
# 3         245600              4
# 4         469347              4
# ...          ...            ...
# 1755      260173              4
# 1756      291560              4
# 1757      250067              4
# 1758      238840              4
# 1759      252333              4
#
# [1760 rows x 16 columns]

# %%
# some of the queries returned no results ('NA', Not Available in audio features rows)
repository['time_signature'].value_counts()
# Out:
# 4     1686
# NA      46
# 3       27
# 1        1
# Name: time_signature, dtype: int64

# %%
# . I'm going to remove this rows with no audio features
repository=repository[~(repository['time_signature']=='NA')]

# %%
repository.to_csv('list.csv')
